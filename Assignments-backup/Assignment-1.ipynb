# %% [markdown]
# # Assignment 1 - Titanic Case Study

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Practice on Pandas and Data Visualization

# %%
overall_survival_rate = df['Survived'].mean()
print(f"Overall Survival Rate: {overall_survival_rate:.2%}")
# Out:
# Overall Survival Rate: 38.38%

# %% [markdown]
# - 1. What is the overall survival rate of passengers aboard the Titanic?

# %% [markdown]
# 38.38%

# %%
survival_by_class = df.groupby("Pclass")['Survived'].mean()
print("Survival Rate by Class:\n", survival_by_class)
# Out:
# Survival Rate by Class:
#  Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %% [markdown]
# - 2. How does the survival rate vary by passenger class (Pclass)?

# %% [markdown]
# Its sort of decreasing!

# %%
avg_age = df.groupby("Survived")['Age'].mean()
print("Average Age (0 = Did not survive, 1 = Survived):\n", avg_age)
# Out:
# Average Age (0 = Did not survive, 1 = Survived):
#  Survived
# 0    30.626179
# 1    28.343690
# Name: Age, dtype: float64

# %% [markdown]
# - 3. What is the average age of passengers who survived vs. those who did not survive?

# %% [markdown]
# Passengers who didn't survived  have average age of 30

# %% [markdown]
# Passengers who survived have avg age of 28

# %% [markdown]
# - 4. How many passengers embarked from each port (Embarked), and what are their survival rates?

# %%
embarked_counts = df['Embarked'].value_counts()
print("Passenger Count by Embarkation Port:\n", embarked_counts)

survival_by_embark = df.groupby("Embarked")['Survived'].mean()
print("\nSurvival Rate by Embarkation Port:\n", survival_by_embark)
# Out:
# Passenger Count by Embarkation Port:
#  Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64
#
# Survival Rate by Embarkation Port:
#  Embarked
# C    0.553571
# Q    0.389610
# S    0.336957
# Name: Survived, dtype: float64

# %% [markdown]
# - 5. What is the distribution of fare prices paid by passengers, and does fare impact survival chances?

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Fare'], bins=30, kde=True)
plt.title("Distribution of Fare")
plt.show()

# Compare fare for survivors vs non-survivors
plt.figure(figsize=(8,5))
sns.boxplot(x="Survived", y="Fare", data=df)
plt.title("Fare vs Survival")
plt.show()

# %% [markdown]
# - 6. Plot the count of passengers by passenger class (Pclass).

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Pclass", data=df)
plt.title("Passenger Count by Class")
plt.show()

# %% [markdown]
# - 7. Visualize the survival rate with respect to gender using a bar chart.

# %%
plt.figure(figsize=(6,4))
sns.barplot(x="Sex", y="Survived", data=df)
plt.title("Survival Rate by Gender")
plt.show()

# %% [markdown]
# - 8. Show the age distribution of passengers using a histogram or KDE plot.

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Age'], bins=30, kde=True)
plt.title("Age Distribution of Passengers")
plt.show()

# %% [markdown]
# - 9. Create a boxplot comparing fares across different passenger classes.

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x="Pclass", y="Fare", data=df)
plt.title("Fare Distribution by Class")
plt.show()

# %% [markdown]
# - 10. Visualize survival count by embarkation port (Embarked) with a stacked bar chart.

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x="Pclass", y="Fare", data=df)
plt.title("Fare Distribution by Class")
plt.show()

# %% [markdown]
# - 11. Display a heatmap of the correlation matrix of numerical features in the dataset.

# %%
embark_survival = pd.crosstab(df['Embarked'], df['Survived'])

embark_survival.plot(kind="bar", stacked=True, figsize=(8,5))
plt.title("Survival Count by Embarkation Port")
plt.xlabel("Embarked")
plt.ylabel("Count")
plt.legend(title="Survived")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()
